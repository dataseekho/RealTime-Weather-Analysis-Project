# %% [markdown]
# # What is pip?
#
# `pip` is the standard package manager for Python. It allows you to install and manage additional packages that are not part of the Python standard library.

# %%
pip install pandas

# %% [markdown]
# # **Why Use Pandas?**
#
# ### **Data Cleaning and Preprocessing**: Pandas offers a wide range of functions for data cleaning, preprocessing, and transformation, making it easy to prepare data for analysis.
# ### **Data Analysis**: Pandas simplifies data analysis tasks such as aggregation, grouping, and statistical analysis, allowing users to gain insights from their data quickly.
# ### **In short, Pandas is sort of like a spreadsheet, but one you work with using code, not Microsoft Excel.**

# %% [markdown]
# ## **Basic Data Structures of Pandas**

# %% [markdown]
# ![Screenshot 2024-09-09 at 6.07.41 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-09 at 6.07.55 PM.png](data:image/png;base64,...)

# %% [markdown]
# .
#
# # **Series**
# A Series is a one-dimensional labeled array capable of holding any data type (integers, strings, floating-point numbers, Python objects, etc.).

# %%
import pandas as pd

# Creating a Series from a list
s = pd.Series([1, 2, 3, 4, 5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# # **DataFrame**
# A DataFrame is a two-dimensional labeled data structure with columns of potentially different types. It is similar to a spreadsheet or SQL table.

# %% [markdown]
# ![Screenshot 2024-09-09 at 6.07.48 PM.png](data:image/png;base64,...)

# %%
# Creating a DataFrame from a dictionary
data = {'Name': ['Ali', 'Ayesha', 'Ahmed', 'Umar'],
        'Age': [25, 30, 35, 40]}
df = pd.DataFrame(data)
df.head(100)
# Out:
#      Name  Age
# 0     Ali   25
# 1  Ayesha   30
# 2   Ahmed   35
# 3    Umar   40

# %%
print(df)
# Out:
#      Name  Age
# 0     Ali   25
# 1  Ayesha   30
# 2   Ahmed   35
# 3    Umar   40

# %% [markdown]
# ### Detailed Step-by-Step Guide
#
# #### 1. **Importing Pandas and Reading the CSV File**

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('student_list.csv')

# Display the first few rows of the DataFrame
print("First few rows of the DataFrame:")
df.head()
# Out:
# First few rows of the DataFrame:
#    StudentID           Name  Age  Grade  Score
# 0          1    Ayesha Khan   15     10   88.0
# 1          2      Ahmed Ali   14      9   92.0
# 2          3  Fatima Baloch   16     11   85.0
# 3          4    Bilal Malik   15     10    NaN
# 4          5      Sana Shah   14      9    NaN

# %%
df.head(10)
# Out:
#    StudentID           Name  Age  Grade  Score
# 0          1    Ayesha Khan   15     10   88.0
# 1          2      Ahmed Ali   14      9   92.0
# 2          3  Fatima Baloch   16     11   85.0
# 3          4    Bilal Malik   15     10    NaN
# 4          5      Sana Shah   14      9    NaN
# 5          6   Imran Sheikh   16     11    NaN
# 6          7     Hina Javed   15     10   91.0
# 7          8       Ali Raza   14      9   87.0
# 8          9   Sara Hussain   16     11   90.0
# 9         10  Usman Qureshi   15     10   83.0

# %% [markdown]
# ## 2. **Inspecting the Data**
#
# - **Basic Information:**

# %%
# Display basic information about the DataFrame
print("\nBasic Information:")
df.info()
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  10 non-null     int64
#  1   Name       10 non-null     object
#  2   Age        10 non-null     int64
#  3   Grade      10 non-null     int64
#  4   Score      7 non-null      float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 528.0+ bytes

# %% [markdown]
# - **Column Names:**

# %%
# Display column names
print("\nColumn Names:")
df.columns
# Out:
# Column Names:
# Index(['StudentID', 'Name', 'Age', 'Grade', 'Score'], dtype='object')

# %% [markdown]
# - **Checking for Missing Values:**

# %%
# Check for missing values
print("\nMissing Values:")
df.isnull()
# Out:
# Missing Values:
#    StudentID   Name    Age  Grade  Score
# 0      False  False  False  False  False
# 1      False  False  False  False  False
# 2      False  False  False  False  False
# 3      False  False  False  False   True
# 4      False  False  False  False   True
# 5      False  False  False  False   True
# 6      False  False  False  False  False
# 7      False  False  False  False  False
# 8      False  False  False  False  False
# 9      False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# StudentID    0
# Name         0
# Age          0
# Grade        0
# Score        3
# dtype: int64

# %% [markdown]
# - **Statistical Summary:**

# %%
# Display basic statistical details
print("\nStatistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#        StudentID        Age      Grade      Score
# count   10.00000  10.000000  10.000000   7.000000
# mean     5.50000  15.000000  10.000000  88.000000
# std      3.02765   0.816497   0.816497   3.265986
# min      1.00000  14.000000   9.000000  83.000000
# 25%      3.25000  14.250000   9.250000  86.000000
# 50%      5.50000  15.000000  10.000000  88.000000
# 75%      7.75000  15.750000  10.750000  90.500000
# max     10.00000  16.000000  11.000000  92.000000

# %%
df['Age']
# Out:
# 0    15
# 1    14
# 2    16
# 3    15
# 4    14
# 5    16
# 6    15
# 7    14
# 8    16
# 9    15
# Name: Age, dtype: int64

# %%
df
# Out:
#    StudentID           Name  Age  Grade  Score
# 0          1    Ayesha Khan   15     10   88.0
# 1          2      Ahmed Ali   14      9   92.0
# 2          3  Fatima Baloch   16     11   85.0
# 3          4    Bilal Malik   15     10    NaN
# 4          5      Sana Shah   14      9    NaN
# 5          6   Imran Sheikh   16     11    NaN
# 6          7     Hina Javed   15     10   91.0
# 7          8       Ali Raza   14      9   87.0
# 8          9   Sara Hussain   16     11   90.0
# 9         10  Usman Qureshi   15     10   83.0

# %% [markdown]
# ### **Viewing Specific Columns:**

# %%
# Display only the 'Name' and 'Score' columns
print("\nNames and Scores:")
df[['Name', 'Score','Grade']]
# Out:
# Names and Scores:
#             Name  Score  Grade
# 0    Ayesha Khan   88.0     10
# 1      Ahmed Ali   92.0      9
# 2  Fatima Baloch   85.0     11
# 3    Bilal Malik    NaN     10
# 4      Sana Shah    NaN      9
# 5   Imran Sheikh    NaN     11
# 6     Hina Javed   91.0     10
# 7       Ali Raza   87.0      9
# 8   Sara Hussain   90.0     11
# 9  Usman Qureshi   83.0     10

# %%
df
# Out:
#    StudentID           Name  Age  Grade  Score
# 0          1    Ayesha Khan   15     10   88.0
# 1          2      Ahmed Ali   14      9   92.0
# 2          3  Fatima Baloch   16     11   85.0
# 3          4    Bilal Malik   15     10    NaN
# 4          5      Sana Shah   14      9    NaN
# 5          6   Imran Sheikh   16     11    NaN
# 6          7     Hina Javed   15     10   91.0
# 7          8       Ali Raza   14      9   87.0
# 8          9   Sara Hussain   16     11   90.0
# 9         10  Usman Qureshi   15     10   83.0

# %%
var = 78

# %%
df[df['Score'] > 90]
# Out:
#    StudentID        Name  Age  Grade  Score
# 1          2   Ahmed Ali   14      9   92.0
# 6          7  Hina Javed   15     10   91.0

# %%
df[df['Age'] > 15]
# Out:
#    StudentID           Name  Age  Grade  Score
# 2          3  Fatima Baloch   16     11   85.0
# 5          6   Imran Sheikh   16     11    NaN
# 8          9   Sara Hussain   16     11   90.0

# %% [markdown]
# ### **Filtering Data**

# %%
# Filter students older than 15 years
older_students = df[df['Age'] > 15]
print("\nStudents older than 15:")
older_students
# Out:
# Students older than 15:
#    StudentID           Name  Age  Grade  Score
# 2          3  Fatima Baloch   16     11   85.0
# 5          6   Imran Sheikh   16     11    NaN
# 8          9   Sara Hussain   16     11   90.0

# %%
older_students.tail(1)
# Out:
#    StudentID          Name  Age  Grade  Score
# 8          9  Sara Hussain   16     11   90.0

# %%
df['Column_Name'] = df['Age'] >= 16

# %%
df
# Out:
#    StudentID           Name  Age  Grade  Score  Column_Name
# 0          1    Ayesha Khan   15     10   88.0        False
# 1          2      Ahmed Ali   14      9   92.0        False
# 2          3  Fatima Baloch   16     11   85.0         True
# 3          4    Bilal Malik   15     10    NaN        False
# 4          5      Sana Shah   14      9    NaN        False
# 5          6   Imran Sheikh   16     11    NaN         True
# 6          7     Hina Javed   15     10   91.0        False
# 7          8       Ali Raza   14      9   87.0        False
# 8          9   Sara Hussain   16     11   90.0         True
# 9         10  Usman Qureshi   15     10   83.0        False

# %% [markdown]
# ### **Add a New Column Based on Existing Data:**

# %%
# Add a column 'Pass' based on Score
df['Pass'] = df['Score'] >= 85
print("\nDataFrame with 'Pass' column:")
df
# Out:
# DataFrame with 'Pass' column:
#    StudentID           Name  Age  Grade  Score  Column_Name   Pass
# 0          1    Ayesha Khan   15     10   88.0        False   True
# 1          2      Ahmed Ali   14      9   92.0        False   True
# 2          3  Fatima Baloch   16     11   85.0         True   True
# 3          4    Bilal Malik   15     10    NaN        False  False
# 4          5      Sana Shah   14      9    NaN        False  False
# 5          6   Imran Sheikh   16     11    NaN         True  False
# 6          7     Hina Javed   15     10   91.0        False   True
# 7          8       Ali Raza   14      9   87.0        False   True
# 8          9   Sara Hussain   16     11   90.0         True   True
# 9         10  Usman Qureshi   15     10   83.0        False  False

# %%
df[df['Pass'] == True]
# Out:
#    StudentID           Name  Age  Grade  Score  Column_Name  Pass
# 0          1    Ayesha Khan   15     10   88.0        False  True
# 1          2      Ahmed Ali   14      9   92.0        False  True
# 2          3  Fatima Baloch   16     11   85.0         True  True
# 6          7     Hina Javed   15     10   91.0        False  True
# 7          8       Ali Raza   14      9   87.0        False  True
# 8          9   Sara Hussain   16     11   90.0         True  True

# %%
df.head()
# Out:
#    StudentID           Name  Age  Grade  Score  Column_Name   Pass
# 0          1    Ayesha Khan   15     10   88.0        False   True
# 1          2      Ahmed Ali   14      9   92.0        False   True
# 2          3  Fatima Baloch   16     11   85.0         True   True
# 3          4    Bilal Malik   15     10    NaN        False  False
# 4          5      Sana Shah   14      9    NaN        False  False

# %% [markdown]
# ### **Group by Grade and Calculate Average Score:**

# %%
# Group by 'Grade' and calculate the mean Score
grade_avg_scores = df.groupby('Grade')['Score'].min()
print("\nAverage Score by Grade:")
grade_avg_scores
# Out:
# Average Score by Grade:
# Grade
# 9     87.0
# 10    83.0
# 11    85.0
# Name: Score, dtype: float64

# %%
df
# Out:
#    StudentID           Name  Age  Grade  Score  Column_Name   Pass
# 0          1    Ayesha Khan   15     10   88.0        False   True
# 1          2      Ahmed Ali   14      9   92.0        False   True
# 2          3  Fatima Baloch   16     11   85.0         True   True
# 3          4    Bilal Malik   15     10    NaN        False  False
# 4          5      Sana Shah   14      9    NaN        False  False
# 5          6   Imran Sheikh   16     11    NaN         True  False
# 6          7     Hina Javed   15     10   91.0        False   True
# 7          8       Ali Raza   14      9   87.0        False   True
# 8          9   Sara Hussain   16     11   90.0         True   True
# 9         10  Usman Qureshi   15     10   83.0        False  False

# %%
column_name.fillna(which_column_want_to_replace)

# %% [markdown]
# ## **Fill Missing Data:**

# %%
df.describe()
# Out:
#        StudentID        Age      Grade      Score
# count   10.00000  10.000000  10.000000  10.000000
# mean     5.50000  15.000000  10.000000  88.000000
# std      3.02765   0.816497   0.816497   2.666667
# min      1.00000  14.000000   9.000000  83.000000
# 25%      3.25000  14.250000   9.250000  87.250000
# 50%      5.50000  15.000000  10.000000  88.000000
# 75%      7.75000  15.750000  10.750000  89.500000
# max     10.00000  16.000000  11.000000  92.000000

# %%
# Fill missing data with the mean Score
df['Score'].fillna(df['Score'].mean(), inplace=True)
print("\nDataFrame with Missing Scores Filled:")
df
# Out:
# DataFrame with Missing Scores Filled:
#    StudentID           Name  Age  Grade  Score  Column_Name   Pass
# 0          1    Ayesha Khan   15     10   88.0        False   True
# 1          2      Ahmed Ali   14      9   92.0        False   True
# 2          3  Fatima Baloch   16     11   85.0         True   True
# 3          4    Bilal Malik   15     10   88.0        False  False
# 4          5      Sana Shah   14      9   88.0        False  False
# 5          6   Imran Sheikh   16     11   88.0         True  False
# 6          7     Hina Javed   15     10   91.0        False   True
# 7          8       Ali Raza   14      9   87.0        False   True
# 8          9   Sara Hussain   16     11   90.0         True   True
# 9         10  Usman Qureshi   15     10   83.0        False  False

# %% [markdown]
# ### **Drop Rows with Missing Data:**

# %%
# Drop rows with missing data
df_dropped = df.dropna()
print("\nDataFrame with Rows Containing Missing Data Dropped:")
df_dropped
# Out:
# DataFrame with Rows Containing Missing Data Dropped:
#    StudentID           Name  Age  Grade  Score  Column_Name   Pass
# 0          1    Ayesha Khan   15     10   88.0        False   True
# 1          2      Ahmed Ali   14      9   92.0        False   True
# 2          3  Fatima Baloch   16     11   85.0         True   True
# 6          7     Hina Javed   15     10   91.0        False   True
# 7          8       Ali Raza   14      9   87.0        False   True
# 8          9   Sara Hussain   16     11   90.0         True   True
# 9         10  Usman Qureshi   15     10   83.0        False  False

# %% [markdown]
# ### **Saving Changes to a CSV File**

# %%
df
# Out:
#    StudentID           Name  Age  Grade  Score  Column_Name   Pass
# 0          1    Ayesha Khan   15     10   88.0        False   True
# 1          2      Ahmed Ali   14      9   92.0        False   True
# 2          3  Fatima Baloch   16     11   85.0         True   True
# 3          4    Bilal Malik   15     10   88.0        False  False
# 4          5      Sana Shah   14      9   88.0        False  False
# 5          6   Imran Sheikh   16     11   88.0         True  False
# 6          7     Hina Javed   15     10   91.0        False   True
# 7          8       Ali Raza   14      9   87.0        False   True
# 8          9   Sara Hussain   16     11   90.0         True   True
# 9         10  Usman Qureshi   15     10   83.0        False  False

# %%
# Save the modified DataFrame to a new CSV file
df.to_csv('students_modified.csv', index=False)
print("\nModified DataFrame saved to 'students_modified.csv'")
# Out:
# Modified DataFrame saved to 'students_modified.csv'
